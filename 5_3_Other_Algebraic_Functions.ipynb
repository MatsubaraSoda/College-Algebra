# %% [markdown]
# <a href="https://colab.research.google.com/github/MatsubaraSoda/College-Algebra/blob/main/5_3_Other_Algebraic_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Definition 5.4.** Let $x$ be a real number and $n$ a natural number. If $n$ is odd, the **principal $\boldsymbol{n^{th}}$ root** of $x$, denoted $\sqrt[n]{x}$ is the unique real number satisfying $(\sqrt[n]{x})^n=x$. If $n$ is even, $\sqrt[n]{x}$ is defined similarly provided $x\geq 0$ and $\sqrt[n]{x}\geq 0$. The **index** is the number $n$ and the **radicand** is the number $x$. For $n=2$, we write $\sqrt{x}$ instead of $\sqrt[2]{x}$.

# %% [markdown]
# **Theorem 5.6. Properties of Radicals:** Let $x$ and $y$ be real numbers and $m$ and $n$ be natural numbers. If $\sqrt[n]{x}$, $\sqrt[n]{y}$ are real numbers, then
#
# - **Product Rule:** $\sqrt[n]{xy}=\sqrt[n]{x}\sqrt[n]{y}$
#
# - **Powers of Radicals:** $\sqrt[n]{x^m}=(\sqrt[n]{x})^m$
#
# - **Quotient Rule:** $\sqrt[n]{\frac{x}{y}}=\frac{\sqrt[n]{x}}{\sqrt[n]{y}}$, provided $y\ne 0$.
#
# - If $n$ is odd, $\sqrt[n]{x^n}=x$; if $n$ is even, $\sqrt[n]{x}=|x|$.

# %% [markdown]
# **Definition 5.5.** Let $x$ be a real number, $m$ an integer and $n$ a natural number.
#
# - $x^{\frac{1}{n}}=\sqrt[n]{x}$ and is defined whenever $\sqrt[n]{x}$ is defined.
#
# - $x^{\frac{m}{n}}=(\sqrt[n]{x}^m)=\sqrt[n]{x^m}$, whenever $(\sqrt[n]{x})^m$ is defined.

# %% [markdown]
# <center><b>Steps for Constructing a Sign Diagram for an Algebraic Function</b></center>
#
# Suppose $f$ is an algebraic function.
#
# 1. Place any values excluded from the domain of $f$ on the number line with an '‽' above them.
#
# 2. Find the zeros of $f$ and place them on the number line with the number 0 above them.
#
# 3. Choose a test value in each of the intervals determined in steps 1 and 2.
#
# 4. Determine the sign of $f(x)$ for each test value in step 3, and write that sign above the corresponding interval.

# %% [markdown]
# 🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercises 1 - 10
#
# For each function in Exercises 1 - 10 below
#
# - Find its domain.
#
# - Create a sign diagram.
#
# - Use your calculator to help you sketch its graph and identify any vertical or horizontal asymptotes, 'unusual steepness' or cusps.

# %% [markdown]
# ### 1. $f(x)=\sqrt{1-x^2}$

# %%
x = np.linspace(-1, 1, 10000)
f = np.sqrt(1 - x**2)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\sqrt{1-x^2}$')

axs.axis('equal')
axs.set(xlim=(-2,2), ylim=(-2,2))

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()

# %% [markdown]
# ### 2. $f(x)=\sqrt{x^2-1}$

# %%
x = np.linspace(-4, 4, 10000)
f = np.sqrt(x**2 - 1)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\sqrt{x^2-1}$')

axs.set_aspect('equal', 'box')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-3-e2df89282bae>:2: RuntimeWarning: invalid value encountered in sqrt
#   f = np.sqrt(x**2 - 1)

# %% [markdown]
# ### 3. $f(x)=x\sqrt{1-x^2}$

# %%
x = np.linspace(-2, 2, 10000)
f = x * np.sqrt(1 - x**2)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=x\sqrt{1-x^2}$')

axs.set_aspect('equal', 'box')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-4-02b5aaf32390>:2: RuntimeWarning: invalid value encountered in sqrt
#   f = x * np.sqrt(1 - x**2)

# %% [markdown]
# ### 4. $f(x)=x\sqrt{x^2-1}$

# %%
x = np.linspace(-2, 2, 10000)
f = x * np.sqrt(x**2 - 1)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=x\sqrt{x^2-1}$')

axs.axis('equal')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-5-935cf17b20f3>:2: RuntimeWarning: invalid value encountered in sqrt
#   f = x * np.sqrt(x**2 - 1)

# %% [markdown]
# ### 5. $f(x)=\sqrt[4]{\frac{16x}{x^2-9}}$

# %%
x = np.linspace(-10, 10, 10000)
f = np.sqrt(16*x / (x**2-9))

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\sqrt[4]{\frac{16x}{x^2-9}}$')

axs.axis('equal')
axs.set(xlim=(-10,10), ylim=(-10,10))

axs.axvline(-3, color='orange', linestyle='dashed', label=r'x=-3')
axs.axvline(3, color='orange', linestyle='dashed', label=r'x=3')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-6-78c85e7df086>:2: RuntimeWarning: invalid value encountered in sqrt
#   f = np.sqrt(16*x / (x**2-9))

# %% [markdown]
# ### 6. $f(x)=\frac{5x}{\sqrt[3]{x^3+8}}$

# %%
x = np.linspace(-10, 10, 10000)

f = 5*x / np.cbrt(x**3 + 8)
f = np.ma.masked_where(np.logical_or(f<-10, f>10), f)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\frac{5x}{\sqrt[3]{x^3+8}}$')

axs.axis('equal')
axs.set(xlim=(-10,10), ylim=(-10,10))

axs.axvline(-2, color='orange', linestyle='dashed', label=r'x=-2')
axs.axhline(5, color='purple', linestyle='dashed', label=r'y=5')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()

# %% [markdown]
# ### 7. $f(x)=x^{\frac{2}{3}}(x-7)^{\frac{1}{3}}$

# %%
x = np.linspace(-10, 10, 10000)

f = np.power(np.cbrt(x), 2) * np.cbrt(x-7)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=x^{\frac{2}{3}}(x-7)^{\frac{1}{3}}$')

axs.axis('equal')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()

# %% [markdown]
# ### 8. $f(x)=x^{\frac{3}{2}}(x-7)^\frac{1}{3}$

# %%
x = np.linspace(-10, 10, 10000)

f = np.power(np.sqrt(x), 3) * np.cbrt(x-7)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=x^{\frac{3}{2}}(x-7)^\frac{1}{3}$')

axs.axis('equal')
axs.set(xlim=(-10,10), ylim=(-20,20))

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-9-662d9751a7ea>:3: RuntimeWarning: invalid value encountered in sqrt
#   f = np.power(np.sqrt(x), 3) * np.cbrt(x-7)

# %% [markdown]
# ### 9. $f(x)=\sqrt{x(x+5)(x-4)}$

# %%
x = np.linspace(-10, 10, 10000)

f = np.sqrt(x * (x + 5) * (x - 4))

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\sqrt{x(x+5)(x-4)}$')

axs.axis('equal')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()
# Out:
# <ipython-input-10-741d432ad02f>:3: RuntimeWarning: invalid value encountered in sqrt
#   f = np.sqrt(x * (x + 5) * (x - 4))

# %% [markdown]
# ### 10. $f(x)=\sqrt[3]{x^3+3x^2-6x-8}$

# %%
x = np.linspace(-10, 10, 10000)

f = np.cbrt(x**3 + 3*x**2 - 6*x - 8)

fig, axs = plt.subplots()

axs.plot(x, f, label=r'$f(x)=\sqrt[3]{x^3+3x^2-6x-8}$')

axs.axis('equal')

axs.axhline(0, color='black', linewidth=0.25)
axs.axvline(0, color='black', linewidth=0.25)

axs.legend()
plt.show()

# %% [markdown]
# ## Exercises 11 - 16
#
# In Exercises 11 - 16, sketch the graph of $y=g(x)$ by starting with the graph of $y=f(x)$ and using the transformations presented in Section 1.7.

# %% [markdown]
# ### 11. $f(x)=\sqrt[3]{x},\ g(x)=\sqrt[3]{x-1}-2$

# %% [markdown]
# ### 12. $f(x)=\sqrt[3]{x},\ g(x)=-2\sqrt[3]{x+1}+4$

# %% [markdown]
# ### 13. $f(x)=\sqrt[4]{x},\ g(x)=\sqrt[4]{x-1}-2$

# %% [markdown]
# ### 14. $f(x)=\sqrt[4]{x},\ g(x)=3\sqrt[4]{x-7}-1$

# %% [markdown]
# ### 15. $f(x)=\sqrt[5]{x},\ g(x)=\sqrt[5]{x+2}+3$

# %% [markdown]
# ### 16. $\sqrt[8]{x},\ g(x)=\sqrt[8]{-x}-2$
