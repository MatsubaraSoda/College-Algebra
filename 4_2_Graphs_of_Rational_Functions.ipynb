# %% [markdown]
# <a href="https://colab.research.google.com/github/MatsubaraSoda/College-Algebra/blob/main/4_2_Graphs_of_Rational_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Steps for Constructing a Sign Diagram for a Rational Function**
#
# Suppose $r$ is a rational function.
#
# 1. Place and values excluded from the domain of $r$ on the number line with an '&#8253;' above them.
#
# 2. Find the zeros of $r$ and place them on the number line with the number 0 above them.
#
# 3. Choose a test value in each of the intervals determined in steps 1 and 2.
#
# 4. Determine the sign of $r(x)$ for each test value in step 3, and write that sign above the corresponding interval.

# %% [markdown]
# **Steps for Graphing Rational Functions**
#
# Suppose the domain of $r$.
#
# 1. Find the domain of $r$.
#
# 2. Reduce $r(x)$ to lowest terms, if applicable.
#
# 3. Find the $x$- and $y$-interceptes of the graph of $y=r(x)$, if they exist.
#
# 4. Determine the location of any vertical asymptotes or holes in the graph, if they exist. Analyze the behavior of $r$ on either side of the vertical asymptotes, if applicable.
#
# 5. Analyze the end behavior of $r$. Find the horizontal or slant asymptote, if one exists.
#
# 6. Use a sign diagram and plot additional points, as needed, to sketch the graph of $y=r(x)$.

# %% [markdown]
# 🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍🐱‍🏍

# %% [markdown]
# ## Exercise 23
#
# Let $g(x)=\frac{x^4-8x^3+24x^2-72x+135}{x^3-9x^2+15x-7}$. With the help of your classmates, find the $x$- and $y$-intercepts of the graph of $g$. Find the intervals on which the function is increasing, the intervals on which it is decreasing and the local extrema. Find all of the asymptotes of the graph of $g$ and any holes in the graph, if they exist. Be sure to show all of your work including any polynomial or synthetic division. Sketch the graph of $g$, using more than one picture if necessary to show all of the important features of the graph.

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

x = sp.Symbol('x')
p = x**4 - 8*x**3 + 24*x**2 - 72*x + 135
q = x**3 - 9*x**2 + 15*x - 7
g = p / q

print("The real zeros of q(x):" , sp.solve(sp.Eq(q, 0), x), '\n')

print("The lowest term of g(x):", sp.simplify(g), '\n')

print("The result of synthetic division:", sp.div(p,q), '\n')

x_values = np.linspace(-50,50,10000)
x_excluded_values = sol_q
x_values = np.setdiff1d(x_values, x_excluded_values)

upper = -100
lower = 100

y_values = sp.lambdify(x, g, 'numpy')(x_values)
y_values = np.ma.masked_where( (y_values < upper) | (y_values > lower), y_values)

plt.plot(x_values, y_values, label=r'$g(x)=\frac{x^4-8x^3+24x^2-72x+135}{x^3-9x^2+15x-7}$')
plt.xlim(-20,20)
plt.ylim(-20,20)

plt.axvline(1, color='orange', linestyle='dashed', label=r'$x=1$')
plt.axvline(7, color='orange', linestyle='dashed', label=r'$x=7$')

plt.plot(x_values, x_values+1, color='green', linestyle='dashed', label=r'$y=x+1$')

plt.axhline(0, color='black', linestyle='solid', linewidth=0.25)
plt.axvline(0, color='black', linestyle='solid', linewidth=0.25)
plt.title('Graph of Rational Function')
plt.legend()
plt.show()
# Out:
# The real zeros of q(x): [1, 7]
#
# The lowest term of g(x): (x**4 - 8*x**3 + 24*x**2 - 72*x + 135)/(x**3 - 9*x**2 + 15*x - 7)
#
# The result of synthetic division: (x + 1, 18*x**2 - 80*x + 142)
