# %% [markdown]
# <a href="https://colab.research.google.com/github/MatsubaraSoda/College-Algebra/blob/main/3_2_The_Factor_Theorem_and_The_Remainder_Theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Theorem 3.4. Polynomial Division:** Suppose $d(x)$ adn $p(x)$ are nonzero polynomials where the degree of $p$ is greater than or equal to the degree of $d$. There exist two unique polynomials, $q(x)$ and $r(x)$, such that $p(x)=d(x)q(x)+r(x)$, where either $r(x)=0$ or the degree of $r$ is strictly less than the degree of $d$.
#
# > All of the polynomials in Theorem 3.4 have special names. The polynomial $p$ is called the **dividend**; $d$ is the **divisor**; $q$ is the **quotient**; $r$ is the **remainder**. If $r(x)=0$ then $d$ is called a **factor** of $p$. The proof of Theorem 3.4 is usually relegated to a course in Abstract Algebra, but we can still use the result to establish two important facts which are the basis of the rest of the chapter.
#
# ---
#
# **Theorem 3.5. The Remainder Theorem:** Suppose $p$ is a polynomial of degree at least 1 and $c$ is a real number. When $p(x)$ is divided by $x-c$ the remainder is $p(c)$.
#
# > The proof of Theorem 3.5 is a direct consequence of Theorem 3.4. When a polynomial is divided by $x-c$, the remainder is either $0$ or has degree less than the degree of $x-c$. Since $x-c$ is degree 1, the degree of the remainder must be 0, which means the remainder is a constant. Hence, in either case, $p(x)=(x-c)q(x)+r$, where r, the remiander, is a real number, possibly 0. It follows that $p(c)=(c-c)q(c)+r=0\cdot q(c)+r=r$, so we get $r=p(c)$ as required.
#
# ---
#
# **Theorem 3.6. The Factor Theorem:** Suppose $p$ is a nonzero polynomial. The real number $c$ is a zero of $p$ if and only if $(x-c)$ is a factor of $p(x)$.
#
# > The proof of The Factor Theorem is a consequence of what we already know. If $(x-c)$ is a factor of $p(x)$, this means $p(x)=(x-c)q(x)$ for some polynomial $q$. Hence, $p(c)=(c-c)q(c)=0$, so $c$ is a zero of $p$. Conversely, if $c$ is a zero of $p$, then $p(c)=0$. In this case, The Remainder Theorem tells us the remainder when $p(x)$ is divided by $(x-c)$, namely $p(c)$, is 0, which means $(x-c)$ is a factor of $p$. What we have established is the fundamental connection between zeros of polynomials and factors of polynomials.
#
# ---

# %% [markdown]
# **Theorem 3.7.** Suppose $f$ is a polynomial of degree $n \geq 1$. Then $f$ has at most $n$ real zeros, counting multiplicities.
#
# ---
#
# **Connections Between Zeros, Factors and Graphs of Polynomial Functions**
#
# Suppose $p$ is a polynomial function of degree $n\geq 1$. The following statements are equivalent:
#
# - The real number $c$ is a zero of $p$.
# - $p(c)=0$
# - $x=c$ is solution to the polynomial equation $p(x)=0$.
# - $(x-c)$ is a factor of $p(x)$
# - The point $(c,0)$ is an $x$-intercept of the graph of $y=p(x)$
#
# ---
#
# 🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️

# %% [markdown]
# ## Exercises 7 - 20
#
# In exercises 7 - 20 use synthetic division to perform the indicated division. Write the polynomial in the form $p(x)=d(x)q(x)+r(x)$.
#
# <br>

# %% [markdown]
# **The synthetic division tableau:**
#
# $$
# \begin{array}{c}
#  & |
# &  &  &  &  \\
# && ↓ &  &  &  \\ \hline
# &&  &  &  & \boxed{}
# \end{array}
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 7\. $(3x^2-2x+1)\div (x-1)$
# $$
# \begin{array}{c}
# 1 & |
#  & 3 & -2 & 1 \\
# && ↓ & 3 & 1 \\
# \hline
# && 3 & 1 & \boxed{2}
# \end{array}
# $$
#
# $$(3x^2-2x+1)=(x-1)(3x+1)+2$$
#
# <br/>
#
# ---
#
# <br/>
#
# 8\. $(x^2-5)\div (x-5)$
# $$
# \begin{array}{c}
# 5 & |
#  & 1 & 0 & -5 \\
# && ↓ & 5 & 25 \\
# \hline
# && 1 & 5 & \boxed{20} &
# \end{array}
# $$
#
# $$(x^2-5)\div (x-5)=(x-5)(x+5)+20$$
#
# <br/>
#
# ---
#
# <br/>
#
# 9\. $(3-4x-2x^2)\div (x+1)$
#
# $$
# \begin{array}{c}
# -1 & |
#  & -2 & -4 & 3 \\
# && ↓ & 2 & 2 \\
# \hline
# && -2 & -2 & \boxed{5} &
# \end{array}
# $$
#
# $$(3-4x-2x^2)\div (x+1)=(x+1)(-2x-2)+5$$
#
# <br/>
#
# ---
#
# <br/>
#
# 10\. $(4x^2-5x+3)\div (x+3)$
#
# $$
# \begin{array}{c}
# -3 & |
#  & 4 & -5 & 3 \\
# && ↓ & -12 & 51 \\
# \hline
# && 4 & -17 & \boxed{54} &
# \end{array}
# $$
#
# $$(4x^2-5x+3)\div (x+3)=(x+3)(4x-17)+54$$
#
# <br/>
#
# ---
#
# <br/>
#
# 11\. $(x^3+8)\div (x+2)$
# $$
# \begin{array}{c}
# -2 & |
#  & 1 & 0 & 0 & 8 \\
# && ↓ & -2 & 4 & -8 \\
# \hline
# && 1 & -2 & 4 & \boxed{0}&
# \end{array}
# $$
#
# $$(x^3+8)\div (x+2)=(x+2)(x^2-2+4)$$
#
# <br/>
#
# ---
#
# <br/>
#
# 12\. $(4x^3+2x-3)\div (x-3)$
# $$
# \begin{array}{c}
# 3 & |
#  & 4 & 0 & 2 & -3 \\
# && ↓ & 12 & 36 & 114 \\
# \hline
# && 4 & 12 & 38 & \boxed{111}&
# \end{array}
# $$
# $$(4x^3+2x-3)\div (x-3)=(x-3)(4x^2+12x+38)+111$$
#
# <br/>
#
# ---
#
# <br/>
#
# 13\. $(18x^2-15x-25)\div (x-\frac{5}{3})$
# $$
# \begin{array}{c}
# \frac{5}{3} & |
#  & 18 & -15 & -25 &  \\
# && ↓ & 30 & 25 &  \\
# \hline
# && 18 & 15 &  \boxed{0} &
# \end{array}
# $$
# $$(18x^2-15x-25)=(x-\frac{5}{3})(18x+15)$$
#
# <br/>
#
# ---
#
# <br/>
#
# 14\. $(4x^2-1)\div (x-\frac{1}{2})$
# $$
# \begin{array}{c}
# \frac{1}{2} & |
#  & 4 & 0 & -1 &  \\
# && ↓ & 2 & 1 &  \\
# \hline
# && 4 & 2 & \boxed{0}
# \end{array}
# $$
# $$(4x^2-1)=(x-\frac{1}{2})(4x+2)$$
#
# <br/>
#
# ---
#
# <br/>
#
# 15\. $(2x^3+x^2+2x+1)\div (x+\frac{1}{2})$
# $$
# \begin{array}{c}
# -\frac{1}{2} & |
#  & 2 & 1 & 2 & 1 \\
# && ↓ & -1 & 0 & -1 \\
# \hline
# && 2 & 0 & 2 & \boxed{0}
# \end{array}
# $$
# $$(2x^3+x^2+2x+1)=(x+\frac{1}{2})(2x^2+2)$$
#
# <br/>
#
# ---
#
# <br/>
#
# 16\. $(3x^3-x+4)\div (x-\frac{2}{3})$
# $$
# \begin{array}{c}
# \frac{2}{3} & |
#  & 3 & 0 & -1 & 4 \\
# && ↓ & 2 & \frac{4}{3} & \frac{2}{9} \\
# \hline
# && 3 & 2 & \frac{1}{3} & \boxed{\frac{38}{9}}
# \end{array}
# $$
# $$(3x^3-x+4)=(x-\frac{2}{3})(3x^2+2x+\frac{1}{3})+\frac{38}{9}$$
#
# <br/>
#
# ---
#
# <br/>
#
# 17\. $(2x^3-3x+1)\div (x-\frac{1}{2})$
# $$
# \begin{array}{c}
# \frac{1}{2} & |
#  & 2 & 0 & -3 & 1 \\
# && ↓ & 1 & \frac{1}{2} & -\frac{5}{4} \\
# \hline
# && 2 & 1 & -\frac{5}{2} & \boxed{-\frac{1}{4}}
# \end{array}
# $$
# $$(2x^3-3x+1)= (x-\frac{1}{2})(2x^2+x-\frac{5}{2})-\frac{1}{4}$$
#
# <br/>
#
# ---
#
# <br/>
#
# 18\. $(4x^4-12x^3+13x^2-12x+9)\div (x-\frac{3}{2})$
# $$
# \begin{array}{c}
# \frac{3}{2} & |
#  & 4 & -12 & 13 & -12 & 9 \\
# && ↓ & 6 & -9 & 6 & -9\\
# \hline
# && 4 & -6 & 4 & -6 & \boxed{0}
# \end{array}
# $$
# $$(4x^4-12x^3+13x^2-12x+9)= (x-\frac{3}{2})(4x^3-6x^2+4x-6)$$
#
# <br/>
#
# ---
#
# <br/>
#
# 19\. $(x^4-6x^2+9)\div (x-\sqrt{3})$
# $$
# \begin{array}{c}
# \sqrt{3} & |
#  & 1 & 0 & -6 & 0 & 9 \\
# && ↓ & \sqrt{3} & 3 & -3\sqrt{3} & -9\\
# \hline
# && 1 & \sqrt{3} & -3 & -3\sqrt{3} & \boxed{0}
# \end{array}
# $$
# $$(x^4-6x^2+9)= (x-\sqrt{3})(x^3+\sqrt{3}x^2-3x-3\sqrt{3})$$
#
# <br/>
#
# ---
#
# <br/>
#
# 20\. $(x^6-6x^4+12x^2-8)\div (x+\sqrt{2})$
# $$
# \begin{array}{c}
# -\sqrt{2} & |
#  & 1 & 0 & -6 & 0 & 12 & 0 & -8 \\
# && ↓ & -\sqrt{2} & 2 & 4\sqrt{2} & -8 & -4\sqrt{2} & 8\\ \hline
# && 1 & -\sqrt{2} & -4 & 4\sqrt{2} & 4 & -4\sqrt{2} & \boxed{0}
# \end{array}
# $$
#
#
# $$(x^6-6x^4+12x^2-8)= (x+\sqrt{2})(x^5-\sqrt{2}x^4-4x^3+4\sqrt{2}x^2+4x-4\sqrt{2})$$
#
# ---
#
# <br/>

# %% [markdown]
# ## Exercises 21 - 30
#
# In Exercises 21 - 30, determine $p(c)$ using the Remainder Theorem for the given polynomial functions and value of $c$. If $p(x)=0$, factor $p(x)=(x-c)q(x)$.
#
# <br>

# %% [markdown]
# $$
# \begin{array}{c}
#  & |
# &  &  &  &  \\
# && ↓ &  &  &  \\ \hline
# &&  &  &  & \boxed{}
# \end{array}
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 21\. $p(x)=2x^2-x+1,c=4$
# $$
# \begin{array}{c}
# c=4 & |
# & 2 & -1 & 1 &  \\
# && ↓ & 8 & 28 &  \\ \hline
# && 2 & 7 &  \boxed{29}
# \end{array}
# $$
#
# $$
# p(4)=r=29
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 22\. $p(x)=4x^2-33x-180,c=12$
# $$
# \begin{array}{c}
# c=12 & |
# & 4 & -33 & -180 &  \\
# && ↓ & 48 & 180 &  \\ \hline
# && 4 & 15 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(12)=r=0,p(x)=(x-12)(4x+15)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 23\. $p(x)=2x^3-x+6,c=-3$
# $$
# \begin{array}{c}
# c=-3 & |
# & 2 & 0 & -1 & 6 \\
# && ↓ & -6 & 18 & -51 \\ \hline
# && 2 & -6 & 17 & \boxed{-45}
# \end{array}
# $$
#
# $$
# p(-3)=r=-45
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 24\. $p(x)=x^3+2x^2+3x+4,c=-1$
# $$
# \begin{array}{c}
# c=-1 & |
# & 1 & 2 & 3 & 4 \\
# && ↓ & -1 & -1 & -2 \\ \hline
# && 1 & 1 & 2 & \boxed{2}
# \end{array}
# $$
#
# $$
# p(-1)=r=2
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 25\. $p(x)=3x^3-6x^2+4x-8,c=2$
# $$
# \begin{array}{c}
# c=2 & |
# & 3 & -6 & 4 & -8 \\
# && ↓ & 6 & 0 & 8 \\ \hline
# && 3 & 0 & 4 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(2)=r=0,p(x)=(x-2)(3x^2+4)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 26\. $p(x)=8x^3+12x^2+6x+1,c=-\frac{1}{2}$
# $$
# \begin{array}{c}
# c=-\frac{1}{2} & |
# & 8 & 12 & 6 & 1 \\
# && ↓ & -4 & -4 & -1 \\ \hline
# && 8 & 8 & 2 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(-\frac{1}{2})=r=0,p(x)=(x+\frac{1}{2})(8x^2+8x+2)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 27\. $p(x)=x^4-2x^2+4,c=\frac{3}{2}$
# $$
# \begin{array}{c}
# c=\frac{3}{2} & |
# & 1 & 0 & -2 & 0 & 4 \\
# && ↓ & \frac{3}{2} & \frac{9}{4} & \frac{3}{8} & \frac{9}{16} \\ \hline
# && 1 & \frac{3}{2} & \frac{1}{4} & \frac{3}{8} & \boxed{\frac{73}{16}}
# \end{array}
# $$
#
# $$
# p(\frac{3}{2})=r=\frac{73}{16}
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 28\. $p(x)=6x^4-x^2+2,c=-\frac{2}{3}$
# $$
# \begin{array}{c}
# c=-\frac{2}{3} & |
# & 6 & 0 & -1 & 0 & 2 \\
# && ↓ & -4 & \frac{8}{3} & -\frac{10}{9} & \frac{20}{27} \\ \hline
# && 6 & -4 & \frac{5}{3} & -\frac{10}{9} & \boxed{\frac{74}{27}}
# \end{array}
# $$
#
# $$
# p(-\frac{2}{3})=r=\frac{74}{27}
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 29\. $p(x)=x^4+x^3-6x^2-7x-7,c=-\sqrt{7}$
# $$
# \begin{array}{c}
# c=-\sqrt{7} & |
# & 1 & 1 & -6 & -7 & -7 \\
# && ↓ & -\sqrt{7} & 7-\sqrt{7} & 7-\sqrt{7} & 7 \\ \hline
# && 1 & 1-\sqrt{7} & 1-\sqrt{7} & -\sqrt{7} & \boxed{0}
# \end{array}
# $$
#
# $$
# p(-\sqrt{7})=r=0,p(x)=(x+\sqrt{7})(x^3+(1-\sqrt{7})x^2+(1-\sqrt{7})x-\sqrt{7})
# $$
#
#
#
# <br/>
#
# ---
#
# <br/>
#
# 30\. $p(x)=x^2-4x+1,c=2-\sqrt{3}$
# $$
# \begin{array}{c}
# c=2-\sqrt{3} & |
# & 1 & -4 & 1 &  \\
# && ↓ & 2-\sqrt{3} & -1 &  \\ \hline
# && 1 & -(2+\sqrt{3}) &  \boxed{0}
# \end{array}
# $$
#
# $$
# p(2-\sqrt{3})=r=0,p(x)=(x-(2-\sqrt{3}))(x-(2+\sqrt{3}))
# $$

# %% [markdown]
# ## Exercises 31 - 40
#
# In Exercises 31 - 40, you are given a polynomial and one of its zeros. Use the techniques in this section to find the rest of the real zeros and factor the polynomial.
#
# <br>

# %% [markdown]
# $$
# \begin{array}{c}
# c_1 & |
# &  &  &  &  \\
# && ↓ &  &  &  \\ \hline
# c_2 & |
# &  &  &  & \boxed{0}\\
# && ↓ &  &  \\ \hline
# c_3 & |
# &  &  & \boxed{0} \\
# && ↓ &    \\ \hline
# &&  & \boxed{0}
# \end{array}
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 31\. $x^3-6x^2+11x-6,c=1$
# $$
# \begin{array}{c}
# 1 & |
# & 1 & -6 & 11 & -6 \\
# && ↓ & 1 & -5 & 6 \\ \hline
# 2 & |
# & 1 & -5 & 6 & \boxed{0}\\
# && ↓ & 2 & -6 \\ \hline
# 3 & |
# & 1 & -3 & \boxed{0} \\
# && ↓ & 3   \\ \hline
# && 1 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=(x-1)(x-2)(x-3)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 32\. $x^3-24x^2+192x-512,c=8$
#
# $$
# \begin{array}{c}
# 8 & |
# & 1 & -24 & 192 & -512 \\
# && ↓ & 8 & -128 & 512 \\ \hline
# 8 & |
# & 1 & -16 & 64 & \boxed{0} \\
# && ↓ & 8 & -64 \\ \hline
# 8 & |
# & 1 & -8 & \boxed{0} \\
# && ↓ & 8  \\ \hline
# && 1 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=(x-8)^3
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 33\. $3x^3+4x^2-x-2,c=\frac{2}{3}$
# $$
# \begin{array}{c}
# \frac{2}{3} & |
# & 3 & 4 & -1 & -2 \\
# && ↓ & 2 & 4 & 2 \\ \hline
# -1 & |
# & 3 & 6 & 3 & \boxed{0}\\
# && ↓ & -3 & -3 \\ \hline
# -1 & |
# & 3 & 3 & \boxed{0} \\
# && ↓ & -3   \\ \hline
# && 3 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=3(x-\frac{2}{3})(x+1)^2
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 34\. $2x^3-3x^2-11x+6,c=\frac{1}{2}$
# $$
# \begin{array}{c}
# \frac{1}{2} & |
# & 2 & -3 & -11 & 6 \\
# && ↓ & 1 & -1 & -6 \\ \hline
# -2 & |
# & 2 & -2 & -12 & \boxed{0}\\
# && ↓ & -4 & 12 \\ \hline
# 3 & |
# & 2 & -6 & \boxed{0} \\
# && ↓ & 6  \\ \hline
# && 2 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=2(x-\frac{1}{2})(x+2)(x-3)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 35\. $x^3+2x^2-3x-6,c=-2$
#
# $$
# \begin{array}{c}
# -2 & |
# & 1 & 2 & -3 & -6 \\
# && ↓ & -2 & 0 & 6 \\ \hline
# -\sqrt{3} & |
# & 1 & 0 & -3 & \boxed{0}\\
# && ↓ & -\sqrt{3} & 3 \\ \hline
# \sqrt{3} & |
# & 1 & -\sqrt{3} & \boxed{0} \\
# && ↓ &  \sqrt{3}  \\ \hline
# && 1 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=(x+2)(x+\sqrt{3})(x-\sqrt{3})
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 36\. $2x^3-x^2-10x+5,c=\frac{1}{2}$
# $$
# \begin{array}{c}
# \frac{1}{2} & |
# & 2 & -1 & -10 & 5 \\
# && ↓ & 1 & 0 & -5 \\ \hline
# -\sqrt{5} & |
# & 2 & 0 & -10 & \boxed{0}\\
# && ↓ & -2\sqrt{5} & 10 \\ \hline
# \sqrt{5} & |
# & 2 & -2\sqrt{5} & \boxed{0} \\
# && ↓ & 2\sqrt{5}   \\ \hline
# && 2 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=2(x-\frac{1}{2})(x+\sqrt{5})(x-\sqrt{5})
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 37\. $4x^4-28x^3+61x^2-42x+9,c=\frac{1}{2}$ is a zero of multiplicity 2
#
# $$
# \begin{array}{c}
# \frac{1}{2} & |
# & 4 & -28 & 61 & -42 & 9 \\
# && ↓ & 2 & -13 & 24 & -9 \\ \hline
# \frac{1}{2} & |
# & 4 & -26 & 48 & -18 & \boxed{0}\\
# && ↓ & 2 & -12 & 18 \\ \hline
# 3 & |
# & 4 & -24 & 36 & \boxed{0} \\
# && ↓ & 12 & -36 &   \\ \hline
# 3 & |
# & 4 & -12 & \boxed{0} \\
# && \downarrow &  12 \\ \hline
# && 4 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=4(x-\frac{1}{2})^2(x-3)^3
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 38\. $x^5+2x^4-12x^3-38x^2-37x-12,c=-1$ is a zero of multiplicity 3
# $$
# \begin{array}{c}
# -1 & |
# & 1 & 2 & -12 & -38 & -37 & -12 \\
# && ↓ & -1 & -1 & 13 & 25 & 12 \\ \hline
# -1 & |
# & 1 & 1 & -13 & -25 & -12 &\boxed{0}\\
# && ↓ & -1 & 0 & 13 & 12 \\ \hline
# -1 & |
# & 1 & 0 & -13 & -12 &\boxed{0} \\
# && ↓ & -1 & 1 & 12 \\ \hline
# -3  & |
# & 1 & -1 & -12 & \boxed{0} \\
# && \downarrow & -3 & 12  \\ \hline
# 4 & |
# & 1 & -4 & \boxed{0} \\
# && \downarrow & 4 \\ \hline
# && 1 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=(x+1)^3(x+3)(x-4)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 39\. $125x^5-275x^4-2265x^3-3213x^2-1728x-324,c=-\frac{3}{5}$ is a zero of multiplicity 3
#
# $$
# \begin{array}{c}
# -\frac{3}{5} & |
# & 125 & -275 & -2265 & -3213 & -1728 & -324 \\
# && ↓ & -75 & 210 & 1233 & 1188 & 324 \\ \hline
# -\frac{3}{5} & |
# & 125 & -350 & -2055 & -1980 & -540 &\boxed{0}\\
# && ↓ & -75 & 255 & 1080 & 540 \\ \hline
# -\frac{3}{5} & |
# & 125 & -425 & -1800 & -900 &\boxed{0} \\
# && ↓ & -75 & 300 & 900 \\ \hline
# -2  & |
# & 125 & -500 & -1500 & \boxed{0} \\
# && \downarrow & -250 & 1500  \\ \hline
# 6 & |
# & 125 & -750 & \boxed{0} \\
# && \downarrow & 750 \\ \hline
# && 125 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=125(x+\frac{3}{5})^3(x+2)(x-6)
# $$
#
# <br/>
#
# ---
#
# <br/>
#
# 40\. $x^2-2x-2,c=1-\sqrt{3}$
# $$
# \begin{array}{c}
# 1-\sqrt{3} & |
# & 1 & -2 & -2 \\
# && ↓ &  1-\sqrt{3} & 2  \\ \hline
# 1+\sqrt{3} & |
# & 1 & -(1+\sqrt{3}) &  \boxed{0} \\
# && ↓ & 1+\sqrt{3}   \\ \hline
# && 1 & \boxed{0}
# \end{array}
# $$
#
# $$
# p(x)=(x-(1-\sqrt{3}))(x-(1+\sqrt{3}))
# $$
#
# <br/>
#
# ---
#
# <br/>
